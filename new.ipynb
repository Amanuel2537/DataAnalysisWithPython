# %%
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.types)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5f58308f500b> in ?()
#       9 #2 Analyzing data
#      10 import matplotlib.pyplot as plt
#      11 import seaborn as sns
#      12 #matplotlib inline
# ---> 13 print(df.types)
#
# c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\USER\Documents\Pyton\new.py:1
# ----> 1 df.corr()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

df.corr()
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\USER\Documents\Pyton\new.py:20
#      17 print(data_type)
#      18 # To find the corelation between variables
# ---> 20 df.corr()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\USER\Documents\Pyton\new.py:20
#      17 print(data_type)
#      18 # To find the corelation between variables
# ---> 20 df.corr()
#      22 #3 To find the correlation between columns
#      23 my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero'

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)

#ploting scatter plot of "engine-size" and "price".

sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000
# (0.0, 53462.51745446051)

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)

#ploting scatter plot of "engine-size" and "price".

sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)

#printing the correlation between the two data
df[["engine-size","price"]].corr()
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)

#ploting scatter plot of "engine-size" and "price".

sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)

#printing the correlation between the two data
df[["engine-size","price"]].corr()

#printing the plot for highway-mpg with city-mpg
sns.regplot(x="highway-mpg",y="city-mpg",dat=df)
plt.ylim(0,)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\USER\Documents\Pyton\new.py:35
#      32 df[["engine-size","price"]].corr()
#      34 #printing the plot for highway-mpg with city-mpg
# ---> 35 sns.regplot(x="highway-mpg",y="city-mpg",dat=df)
#      36 plt.ylim(0,)
#
# TypeError: regplot() got an unexpected keyword argument 'dat'

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)

#ploting scatter plot of "engine-size" and "price".

sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)

#printing the correlation between the two data
df[["engine-size","price"]].corr()

#printing the plot for highway-mpg with city-mpg
sns.regplot(x="highway-mpg",y="city-mpg",data=df)
plt.ylim(0,)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000
# (0.0, 53397.7647280868)

# %%
#importing DATA
import pandas as pd
import numpy as np

path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(path)
df.head()

#2 Analyzing data
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib inline
print(df.dtypes)

#what is the data type of the column "peak-rpm"
data_type=df["peak-rpm"].dtype
print(data_type)
# To find the corelation between variables

#df.corr()

#3 To find the correlation between columns 
my_corr=df[['bore','stroke','compression-ratio','horsepower']].corr()
print(my_corr)

#ploting scatter plot of "engine-size" and "price".

sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)

#printing the correlation between the two data
df[["engine-size","price"]].corr()

#printing the plot for highway-mpg with city-mpg
sns.regplot(x="highway-mpg",y="city-mpg",data=df)
plt.ylim(0,)

df[["highway-mpg","city-mpg"]].corr()

#using box plot to define catagorical varables

# drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)
#working with descriptive statical analysis
df.describe()
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object
# float64
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km      diesel         gas
# count    201.000000    201.000000  201.000000  201.000000
# mean   13207.129353      9.944145    0.099502    0.900498
# std     7947.066342      2.534599    0.300083    0.300083
# min     5118.000000      4.795918    0.000000    0.000000
# 25%     7775.000000      7.833333    0.000000    1.000000
# 50%    10295.000000      9.791667    0.000000    1.000000
# 75%    16500.000000     12.368421    0.000000    1.000000
# max    45400.000000     18.076923    1.000000    1.000000
